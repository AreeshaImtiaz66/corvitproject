# %%
# !git clone https://github.com/drkhurramiqbal26iu/corvit_project.git
# Out:
# Cloning into 'corvit_project'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 1.11 MiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import fileinput

file_path = '/content/corvit_project/image2vector.py'
old_line = 'image.show()'
new_line = '# image.show()  # Commented out for Colab environment'

with fileinput.FileInput(file_path, inplace=True) as file:
    for line in file:
        print(line.replace(old_line, new_line), end='')

print(f"Successfully commented out 'image.show()' in {file_path}.")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python corvit_project/image2vector.py
# Out:
# Image shape: (3712, 5568, 3)
# Image matrix:
# [[[65 82 89]
#   [73 90 97]
#   [71 88 95]
#   ...
#   [ 8 10  7]
#   [ 8 10  7]
#   [ 8 10  7]]
#
#  [[69 86 93]
#   [72 89 96]
#   [69 86 93]
#   ...
#   [ 8 10  7]
#   [ 8 10  7]
#   [ 8 10  7]]
#
#  [[74 91 98]
#   [70 87 94]
#   [67 84 91]
#   ...
#   [ 8 10  7]
#   [ 8 10  7]
#   [ 8 10  7]]
#
#  ...
#
#  [[36 36 38]
#   [37 37 39]
#   [38 38 40]
#   ...
#   [20 22 19]
#   [18 20 17]
#   [16 18 15]]
#
#  [[31 31 33]
#   [34 34 36]
#   [38 38 40]
#   ...
#   [24 26 23]
#   [22 24 21]
#   [21 23 20]]
#
#  [[28 28 30]
#   [33 33 35]
#   [39 39 41]
#   ...
#   [28 30 27]
#   [27 29 26]
#   [27 29 26]]]
# Error: no "view" mailcap rules found for type "image/png"
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# ...

# %%
import fileinput

file_path = '/content/corvit_project/image2vector.py'
old_line = 'image = Image.open("/content/cat.jpg")'
new_line = 'image = Image.open("/content/corvit_project/cat.jpg")'

with fileinput.FileInput(file_path, inplace=True) as file:
    for line in file:
        print(line.replace(old_line, new_line), end='')

print(f"Successfully updated {file_path} to correct image path.")
# Out:
# Successfully updated /content/corvit_project/image2vector.py to correct image path.
